# %%
import pandas as pd
import matplotlib.pyplot as plt
from mlxtend.plotting import scatterplotmatrix
import numpy as np
from sklearn.impute import SimpleImputer

dataset = pd.read_csv('housing.data2.txt', header=None, sep='\s+')
dataset.columns = ['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']


data_top = dataset.head()
print(data_top)

dataarray = imputer.transform(dataset)

scatterplotmatrix(dataarray,names=dataset.columns, figsize=(50,50))
plt.tight_layout
plt.show
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  MEDV
# 0  0.00632  18.0   2.31     0  0.538  ...  296.0     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  ...  242.0     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07     0  0.469  ...  242.0     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18     0  0.458  ...  222.0     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18     0  0.458  ...  222.0     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]
# <function matplotlib.pyplot.show>

# %% [markdown]
# Within this dataset, I notice a couple of linear relationships. To name a few, the relationship between RM and MEDV, AGE and NOX, and AGE and CRIM
